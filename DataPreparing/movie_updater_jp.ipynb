# %%
from Movie_Updater import make_new_dataset

# country = str(input("Enter Country Name to get movies eg('American') :"))
# year = int(input("Enter Year to get movies eg(2019) :"))
country = "American" 
year = 2020
make_new_dataset(country=country,year=year)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from Movie_Updater import make_new_dataset
#       3 # country = str(input("Enter Country Name to get movies eg('American') :"))
#       4 # year = int(input("Enter Year to get movies eg(2019) :"))
#       5 country = "American"
#
# File ~/Documents/ML & DSA/CompanyProjects/MovieRecommend/DataPreparing/Movie_Updater.py:7
#       5 import os
#       6 import requests
# ----> 7 import boto3
#       8 from botocore.exceptions import NoCredentialsError
#       9 from tmdbv3api import TMDb
#
# File ~/opt/miniconda3/envs/envpytorch/lib/python3.9/site-packages/boto3/__init__.py:17
#      14 import logging
#      16 from boto3.compat import _warn_deprecated_python
# ---> 17 from boto3.session import Session
#      19 __author__ = 'Amazon Web Services'
#      20 __version__ = '1.26.50'
#
# ...
